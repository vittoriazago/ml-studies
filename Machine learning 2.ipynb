# %%
import pandas as pd

uri = "https://gist.githubusercontent.com/guilhermesilveira/2d2efa37d66b6c84a722ea627a897ced/raw/10968b997d885cbded1c92938c7a9912ba41c615/tracking.csv"
dados = pd.read_csv(uri)
dados.head()
# Out:
#    home  how_it_works  contact  bought
# 0     1             1        0       0
# 1     1             1        0       0
# 2     1             1        0       0
# 3     1             1        0       0
# 4     1             1        0       0

# %%
mapa = {
    "home" : "principal",
    "how_it_works" : "como_funciona",
    "contact" : "contato",
    "bought" : "comprou"
}
dados = dados.rename(columns = mapa)

# %%
x = dados[["principal","como_funciona", "contato"]]

# %%
y = dados["comprou"]
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: comprou, dtype: int64

# %%
dados.shape
# Out:
# (99, 4)

# %%
treino_x = x[:75]
treino_y = y[:75]
teste_x = x[75:]
teste_y = y[75:]

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score

modelo = LinearSVC()
modelo.fit(treino_x, treino_y)
previsoes = modelo.predict(teste_x)

acuracia = accuracy_score(teste_y, previsoes) * 100
print("A acuracia foi %.2f%%" % acuracia )
# Out:
# A acuracia foi 95.83%

# %%
from sklearn.model_selection import train_test_split

treino_x, teste_x, treino_y, teste_y = train_test_split(x, y, test_size = 0.25)
print(treino_x.shape)

from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score

modelo = LinearSVC()
modelo.fit(treino_x, treino_y)
previsoes = modelo.predict(teste_x)

acuracia = accuracy_score(teste_y, previsoes) * 100
print("A acuracia foi %.2f%%" % acuracia )
# gera resultados aleatorios
# Out:
# (74, 3)
# A acuracia foi 96.00%

# %%
from sklearn.model_selection import train_test_split

# deixa menos aleatorio separação treino de teste
SEED = 20

treino_x, teste_x, treino_y, teste_y = train_test_split(x, y, random_state = SEED, test_size = 0.25)
print(treino_x.shape)

from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score

modelo = LinearSVC()
modelo.fit(treino_x, treino_y)
previsoes = modelo.predict(teste_x)

acuracia = accuracy_score(teste_y, previsoes) * 100
print("A acuracia foi %.2f%%" % acuracia )
# Out:
# (74, 3)
# A acuracia foi 96.00%

# %%
teste_y.value_counts()
# importante seguir proporção
# Out:
# 0    19
# 1     6
# Name: comprou, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# deixa menos aleatorio separação treino de teste
SEED = 20

# proporção comprou/não comprou no y
treino_x, teste_x, treino_y, teste_y = train_test_split(x, y,
                                                        random_state = SEED,
                                                        test_size = 0.25,
                                                        stratify = y)
print(treino_x.shape)

from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score

modelo = LinearSVC()
modelo.fit(treino_x, treino_y)
previsoes = modelo.predict(teste_x)

acuracia = accuracy_score(teste_y, previsoes) * 100
print("A acuracia foi %.2f%%" % acuracia )
# Out:
# (74, 3)
# A acuracia foi 96.00%

# %%
teste_y.value_counts()
# Out:
# 0    17
# 1     8
# Name: comprou, dtype: int64
